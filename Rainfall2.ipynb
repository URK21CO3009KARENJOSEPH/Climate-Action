# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
path = "drive/My Drive/Colab Notebooks/weatherAUS.csv"
df= pd.read_csv(path)
df
# Out:
# Mounted at /content/drive
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
df.shape
# Out:
# (145460, 23)

# %%
df=df.head(2000)

# %%
df.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp             9
# MaxTemp             9
# Rainfall           20
# Evaporation      2000
# Sunshine         2000
# WindGustDir        28
# WindGustSpeed      28
# WindDir9am        374
# WindDir3pm         36
# WindSpeed9am        7
# WindSpeed3pm       10
# Humidity9am         7
# Humidity3pm         7
# Pressure9am         3
# Pressure3pm         7
# Cloud9am         1180
# Cloud3pm         1125
# Temp9am             7
# Temp3pm             7
# RainToday          20
# RainTomorrow       20
# dtype: int64

# %%
df1=df[['Date','Location','MinTemp','MaxTemp','Rainfall','Humidity9am','Humidity3pm','Pressure9am','Pressure3pm','Temp9am','Temp3pm','RainToday','RainTomorrow']]

# %%
df1.fillna(method='bfill', inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
df1.isnull().sum()
# Out:
# Date            0
# Location        0
# MinTemp         0
# MaxTemp         0
# Rainfall        0
# Humidity9am     0
# Humidity3pm     0
# Pressure9am     0
# Pressure3pm     0
# Temp9am         0
# Temp3pm         0
# RainToday       0
# RainTomorrow    0
# dtype: int64

# %%
df1
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Humidity9am  \
# 0     2008-12-01   Albury     13.4     22.9       0.6         71.0
# 1     2008-12-02   Albury      7.4     25.1       0.0         44.0
# 2     2008-12-03   Albury     12.9     25.7       0.0         38.0
# 3     2008-12-04   Albury      9.2     28.0       0.0         45.0
# 4     2008-12-05   Albury     17.5     32.3       1.0         82.0
# ...          ...      ...      ...      ...       ...          ...
# 1995  2014-08-16   Albury      0.9     15.3       0.0         87.0
# 1996  2014-08-17   Albury      6.6     11.6       0.0         75.0
# 1997  2014-08-18   Albury      7.6     18.3       6.6         81.0
# 1998  2014-08-19   Albury      4.0     18.7       0.0         86.0
# 1999  2014-08-20   Albury      2.0     16.3       0.0         75.0
#
#       Humidity3pm  Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday  \
# 0            22.0       1007.7       1007.1     16.9     21.8        No
# ...

# %%
df1['RainToday']= df1['RainToday'].replace({'Yes':1, 'No':0})
# Out:
# <ipython-input-11-7061e626be81>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['RainToday']= df1['RainToday'].replace({'Yes':1, 'No':0})

# %%
df1['RainToday']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1995    0
# 1996    0
# 1997    1
# 1998    0
# 1999    0
# Name: RainToday, Length: 2000, dtype: int64

# %%
df1['RainTomorrow']= df1['RainTomorrow'].replace({'Yes':1, 'No':0})
# Out:
# <ipython-input-13-b6c59810366a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['RainTomorrow']= df1['RainTomorrow'].replace({'Yes':1, 'No':0})

# %%
df1['RainTomorrow']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1995    0
# 1996    1
# 1997    0
# 1998    0
# 1999    0
# Name: RainTomorrow, Length: 2000, dtype: int64

# %%
df1
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Humidity9am  \
# 0     2008-12-01   Albury     13.4     22.9       0.6         71.0
# 1     2008-12-02   Albury      7.4     25.1       0.0         44.0
# 2     2008-12-03   Albury     12.9     25.7       0.0         38.0
# 3     2008-12-04   Albury      9.2     28.0       0.0         45.0
# 4     2008-12-05   Albury     17.5     32.3       1.0         82.0
# ...          ...      ...      ...      ...       ...          ...
# 1995  2014-08-16   Albury      0.9     15.3       0.0         87.0
# 1996  2014-08-17   Albury      6.6     11.6       0.0         75.0
# 1997  2014-08-18   Albury      7.6     18.3       6.6         81.0
# 1998  2014-08-19   Albury      4.0     18.7       0.0         86.0
# 1999  2014-08-20   Albury      2.0     16.3       0.0         75.0
#
#       Humidity3pm  Pressure9am  Pressure3pm  Temp9am  Temp3pm  RainToday  \
# 0            22.0       1007.7       1007.1     16.9     21.8          0
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, roc_curve, auc
import matplotlib.pyplot as plt

# %%
x=df1[['MinTemp','MaxTemp','Rainfall','Humidity9am','Humidity3pm','Pressure9am','Pressure3pm','Temp9am','Temp3pm']]

# %%
y=df1[['RainToday']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state=1)

# %%
standard_Scalar = StandardScaler()
x_train = standard_Scalar.fit_transform(x_train)
x_test = standard_Scalar.transform(x_test)

# %%
knn = KNeighborsClassifier(n_neighbors=21)
knn.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=21)

# %%
y_pred = knn.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# 0.904
