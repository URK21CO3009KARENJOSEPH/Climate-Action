# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
path = "drive/My Drive/Colab Notebooks/heart.data.csv"
df = pd.read_csv(path)
df
# Out:
# Mounted at /content/drive
#      Unnamed: 0     biking    smoking  heart.disease
# 0             1  30.801246  10.896608      11.769423
# 1             2  65.129215   2.219563       2.854081
# 2             3   1.959665  17.588331      17.177803
# 3             4  44.800196   2.802559       6.816647
# 4             5  69.428454  15.974505       4.062224
# ..          ...        ...        ...            ...
# 493         494  47.660440  27.562464      11.294392
# 494         495  45.097203  21.385620       9.616762
# 495         496   8.279743   6.423720      13.495168
# 496         497  42.345863  20.741328      10.115865
# 497         498  30.774254  23.610175      11.843556
#
# [498 rows x 4 columns]

# %%
bin_edges = range(1,20,498)
df['heart.disease_bins']=pd.cut(df['heart.disease'], bins=bin_edges)
df['heart.disease_bins']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 493    NaN
# 494    NaN
# 495    NaN
# 496    NaN
# 497    NaN
# Name: heart.disease_bins, Length: 498, dtype: category
# Categories (0, interval[int64, right]): []

# %%
from sklearn.model_selection import train_test_split
x=df['smoking'].values

print(x)
print(y)
# Out:
# [10.89660802  2.21956318 17.58833051  2.80255888 15.9745046  29.33317552
#   9.06084577 12.8350208  11.99129728 23.27768343 14.43511838 25.07486857
#  11.02327097  6.64574955  5.99050631 14.09783716 16.84081673  5.75859519
#  12.66286943 22.91747999 14.85510636 26.4049774  26.92496068 23.4319568
#  16.98608636 27.68902698  3.9819621   2.13747529 10.38842643  5.83637276
#   3.96760574 27.78340597 16.85329322 15.24973082 10.33148947 16.75344203
#  23.87372679 24.58454991 21.01214184  4.71612688 22.16582548  1.35287826
#   3.50429632  4.18586919 13.67898283 13.37977678 19.45542859  9.24933257
#  12.48273387 18.94134829  1.8047036  13.06720504 17.3516599  23.81899489
#  20.66297135  1.14796206 22.97600182  4.38838035 12.80499995  7.76393045
#   0.76768013  6.73962196  8.27800911  6.0764383   8.41239665 19.55035826
#  14.30663488 12.86915316 16.66320382 24.59878725  8.70076922 12.74071089
#  18.85751066 23.20948019 23.41899999 17.87439357 25.99371062  3.89904036
# ...

# %%
df.shape
# Out:
# (498, 4)

# %%
y.max()
# Out:
# 20.453496225445

# %%
y.min()
# Out:
# 0.551898154405674

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
x_train=np.array(x_train).reshape(-1,1)
y_train=np.array(y_train).reshape(-1,1)

model=LinearRegression()
model. fit(x_train,y_train)

print ("The coeffecient is:",model. coef_)
print("The interecept is:",model.intercept_)
# Out:
# The coeffecient is: [[0.16629732]]
# The interecept is: [7.49482297]

# %%
y_test=np.array(y_test).reshape(-1,1)
y_pred=model.predict(y_test)
print(y_pred)
# Out:
# [[ 9.45204643]
#  [ 7.96944907]
#  [10.35144565]
#  [ 8.62841308]
#  [ 8.17035985]
#  [ 9.08297002]
#  [ 8.76275804]
#  [10.13140951]
#  [ 8.00493363]
#  [ 9.50676849]
#  [ 8.564156  ]
#  [ 8.92635554]
#  [ 8.61276066]
#  [ 9.25720989]
#  [ 9.83620248]
#  [ 8.9490673 ]
#  [ 8.40003616]
#  [ 9.01848997]
#  [ 9.11575384]
#  [ 8.46903888]
#  [ 9.44461607]
#  [10.16026762]
#  [ 9.98940174]
#  [10.23676742]
#  [ 9.54969368]
#  [ 9.00620699]
#  [ 8.02983708]
#  [ 8.59134079]
#  [ 8.6022667 ]
#  [ 9.40440463]
#  [ 8.822246  ]
#  [ 8.77904778]
#  [ 9.51779937]
#  [ 8.82975879]
#  [ 9.72595884]
#  [10.00381054]
#  [ 8.37285009]
#  [ 9.74110383]
#  [10.15441375]
#  [ 8.66565938]
#  [ 9.69635439]
#  [ 9.41318484]
#  [ 9.63786606]
#  [ 9.30654198]
#  [ 9.73418812]
#  [ 9.54508581]
#  [ 9.89212906]
#  [ 8.62720039]
#  [ 9.3853516 ]
#  [ 9.96024099]
#  [ 7.60855809]
#  [ 9.00627424]
#  [ 8.20266475]
#  [10.46059146]
#  [10.39036046]
#  [ 9.16707646]
#  [ 9.99071859]
#  [ 9.30641363]
# ...

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
import math

print('Mean absolute error:', mean_absolute_error(y_test, y_pred))

print("Mean squared error:", mean_squared_error(y_test, y_pred))
print('variance score:',r2_score(y_test, y_pred))

print('Root Mean Squared Error:',math.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Mean absolute error: 3.339368819744628
# Mean squared error: 15.474582920343687
# variance score: 0.2581718010192585
# Root Mean Squared Error: 3.9337746402588554
